# %% [markdown]
# <a href="https://colab.research.google.com/github/NandakrishnanR/Kaggle_projects/blob/master/newyork_taxt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q opendatasets
import opendatasets as od
url= 'https://www.kaggle.com/competitions/new-york-city-taxi-fare-prediction/overview'
od.download(url)
# Out:
# Downloading new-york-city-taxi-fare-prediction.zip to ./new-york-city-taxi-fare-prediction
# 100%|██████████| 1.56G/1.56G [00:12<00:00, 137MB/s]
# Extracting archive ./new-york-city-taxi-fare-prediction/new-york-city-taxi-fare-prediction.zip to ./new-york-city-taxi-fare-prediction

# %%
import pandas as pd
import numpy as np
test=pd.read_csv('new-york-city-taxi-fare-prediction/test.csv')
test.describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count       9914.000000      9914.000000        9914.000000       9914.000000
# mean         -73.974722        40.751041         -73.973657         40.751743
# std            0.042774         0.033541           0.039072          0.035435
# min          -74.252193        40.573143         -74.263242         40.568973
# 25%          -73.992501        40.736125         -73.991247         40.735254
# 50%          -73.982326        40.753051         -73.980015         40.754065
# 75%          -73.968013        40.767113         -73.964059         40.768757
# max          -72.986532        41.709555         -72.990963         41.696683
#
#        passenger_count
# count      9914.000000
# mean          1.671273
# std           1.278747
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           6.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-176634067.py in <cell line: 0>()
# ----> 1 test=pd.read_csv('new-york-city-taxi-fare-prediction/test.csv')
#       2 test.describe()
#
# NameError: name 'pd' is not defined
